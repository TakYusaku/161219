# %% [markdown]
# <a href="https://colab.research.google.com/github/TakYusaku/161219/blob/master/except0_men_data_description.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display
import pandas as pd
import os
import sys
import copy
import matplotlib.pyplot as plt
from pylab import rcParams
import numpy as np
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_name = '/content/drive/My Drive/Colab Notebooks/2021-03-21_pentathlon/csv files/org files/final_men_2019-world.csv'
data = pd.read_csv(file_name, header=0, index_col=0)

data_n = data.query('Fencing !=0 & Swimming != 0 & Riding != 0 & LaserRun != 0')

data_n = data_n.reset_index()

file_name = '/content/drive/My Drive/Colab Notebooks/2021-03-21_pentathlon/csv files/except0/men/men-except0.csv'
data_n.to_csv(file_name)

# %% [markdown]
# # Original data

# %% [markdown]
# ## Scatter(original)

# %%
sns.pairplot(data.iloc[:,1:], hue='Venue')

# %% [markdown]
# ## Correlation matrix(original)

# %%
data = data.iloc[:, 2:]
display(data.corr())
# Out:
#            Fencing  Swimming    Riding  LaserRun
# Fencing   1.000000  0.053307  0.298419  0.402716
# Swimming  0.053307  1.000000  0.052682  0.046788
# Riding    0.298419  0.052682  1.000000  0.581728
# LaserRun  0.402716  0.046788  0.581728  1.000000

# %% [markdown]
# # expect for 0
# ## data description(expect for 0)

# %%
data2 = data_n.iloc[:,2:].sort_values('Venue')
data2.describe()
# Out:
#           Fencing    Swimming      Riding    LaserRun
# count  204.000000  204.000000  204.000000  204.000000
# mean   205.710784  297.764706  284.931373  617.647059
# std     23.997530    9.369983   16.676735   24.726742
# min    136.000000  273.000000  193.000000  482.000000
# 25%    190.000000  291.000000  281.000000  603.000000
# 50%    208.000000  297.500000  290.000000  620.000000
# 75%    221.000000  305.000000  295.000000  635.000000
# max    282.000000  323.000000  300.000000  670.000000

# %% [markdown]
# ## Scatter(expect for 0)

# %%
sns.pairplot(data2, hue='Venue')

# %% [markdown]
# ## Correlation matrix(expect for 0)

# %%
display(data2.corr())
# Out:
#            Fencing  Swimming    Riding  LaserRun
# Fencing   1.000000  0.102422  0.147906 -0.007910
# Swimming  0.102422  1.000000  0.006422  0.021986
# Riding    0.147906  0.006422  1.000000  0.101746
# LaserRun -0.007910  0.021986  0.101746  1.000000

# %% [markdown]
# ## Histgram(expect for 0)
# ### all

# %%
rcParams['figure.figsize'] = 10, 10
data2.hist()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### BUDAPEST

# %%
data_bud = data2[data2['Venue']=='BUDAPEST']
rcParams['figure.figsize'] = 10, 10
data_bud.hist()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### CAIRO

# %%
data_cai = data2[data2['Venue']=='CAIRO']
rcParams['figure.figsize'] = 10, 10
data_cai.hist()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### PRAGUE

# %%
data_pra = data2[data2['Venue']=='PRAGUE']
rcParams['figure.figsize'] = 10, 10
data_pra.hist()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### SOFIA

# %%
data_sof = data2[data2['Venue']=='SOFIA']
rcParams['figure.figsize'] = 10, 10
data_sof.hist()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### SZÉKESFEHÉRVÁR

# %%
venues = data2['Venue'].unique()
data_sze = data2[data2['Venue']==venues[4]]
rcParams['figure.figsize'] = 10, 10
data_sze.hist()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### TOKYO

# %%
data_tok = data2[data2['Venue']=='TOKYO']
rcParams['figure.figsize'] = 10, 10
data_tok.hist()
plt.tight_layout()
plt.show()

# %% [markdown]
# # log-transformation
# ## data description(log-transformation)

# %%
data2['Fencing'] = data2['Fencing'].apply(np.log)
data2['Swimming'] = data2['Swimming'].apply(np.log)
data2['Riding'] = data2['Riding'].apply(np.log)
data2['LaserRun'] = data2['LaserRun'].apply(np.log)
data2.describe()
# Out:
#           Fencing    Swimming      Riding    LaserRun
# count  204.000000  204.000000  204.000000  204.000000
# mean     5.319536    5.695811    5.650350    6.425092
# std      0.119007    0.031463    0.063555    0.041124
# min      4.912655    5.609472    5.262690    6.177944
# 25%      5.247024    5.673323    5.638355    6.401917
# 50%      5.337538    5.695413    5.669881    6.429719
# 75%      5.398163    5.720312    5.686975    6.453625
# max      5.641907    5.777652    5.703782    6.507278

# %% [markdown]
# ## Scatter(log-transformation)

# %%
sns.pairplot(data2, hue='Venue')

# %% [markdown]
# ## Correlation Matrix(log-transformation)

# %%
display(data2.corr())
# Out:
#            Fencing  Swimming    Riding  LaserRun
# Fencing   1.000000  0.105530  0.152367 -0.002182
# Swimming  0.105530  1.000000  0.002582  0.032146
# Riding    0.152367  0.002582  1.000000  0.095777
# LaserRun -0.002182  0.032146  0.095777  1.000000

# %% [markdown]
# ## Histgram(log-transformation)

# %%
rcParams['figure.figsize'] = 10, 10
data2.hist()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### BUDAPEST

# %%
data_bud = data2[data2['Venue']=='BUDAPEST']
rcParams['figure.figsize'] = 10, 10
data_bud.hist()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### CAIRO

# %%
data_cai = data2[data2['Venue']=='CAIRO']
rcParams['figure.figsize'] = 10, 10
data_cai.hist()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### PRAGUE

# %%
data_pra = data2[data2['Venue']=='PRAGUE']
rcParams['figure.figsize'] = 10, 10
data_pra.hist()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### SOFIA

# %%
data_sof = data2[data2['Venue']=='SOFIA']
rcParams['figure.figsize'] = 10, 10
data_sof.hist()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### SZÉKESFEHÉRVÁR

# %%
venues = data2['Venue'].unique()
data_sze = data2[data2['Venue']==venues[4]]
rcParams['figure.figsize'] = 10, 10
data_sze.hist()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### TOKYO

# %%
data_tok = data2[data2['Venue']=='TOKYO']
rcParams['figure.figsize'] = 10, 10
data_tok.hist()
plt.tight_layout()
plt.show()
